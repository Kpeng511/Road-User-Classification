# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('vrudata.csv')
df = df.rename(columns = {'acc_x': 'acceleration_x', 'acc_y': 'acceleration_y', 'acc_z': 'acceleration_z', 'target': 'is_car'})

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    acceleration_x  acceleration_y  acceleration_z  is_car
# 0       -0.113725        0.083797        9.654618       0
# 1       -0.098162        0.087388        9.630676       0
# 2       -0.099359        0.094571        9.645041       0
# 3       -0.099359        0.089783        9.649830       0
# 4       -0.118513        0.087388        9.634268       0

# %%
df.describe()
# Out:
#        acceleration_x  acceleration_y  acceleration_z         is_car
# count   120000.000000   120000.000000   120000.000000  120000.000000
# mean        -0.354549        5.367115        6.729311       0.500000
# std          1.931744        3.420114        2.588606       0.500002
# min        -12.509735      -19.051361      -19.093689       0.000000
# 25%         -1.116619        1.902695        4.829160       0.000000
# 50%         -0.529119        6.922834        6.459327       0.500000
# 75%         -0.092177        8.182184        9.212952       1.000000
# max         36.782090       13.737244       60.973206       1.000000

# %%
df[df['is_car'] == 1].shape
# Out:
# (60000, 4)

# %%
df[df['is_car'] == 0].shape
# Out:
# (60000, 4)

# %% [markdown]
# From the above, we know that we have perfectly balanced data.

# %%
df.nunique()
# Out:
# acceleration_x    19254
# acceleration_y    20343
# acceleration_z    22292
# is_car                2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   acceleration_x  120000 non-null  float64
#  1   acceleration_y  120000 non-null  float64
#  2   acceleration_z  120000 non-null  float64
#  3   is_car          120000 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 3.7 MB

# %%
# df = df. astype(float)
# converts all string columns to float columns.

# %% [markdown]
# #### Cleaning

# %%
df.isnull().sum()
# Out:
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# is_car            0
# dtype: int64

# %%
#df = df.drop([''], axis = 1)

# %% [markdown]
# #### Visualization

# %%
correlation = df.corr()

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)
# annot - annotation; when True, puts correlation value in cells

# %% [markdown]
# There is little to none multicollinearity in our data.

# %% [markdown]
# acc_y highly correlated to target variables. possible reason: car travelling at higher speeds prior to hitting brakes compared to pedestrains or bikers.

# %%
sns.pairplot(df.drop(['is_car'], axis = 1))

# %%
sns.relplot(x = 'acceleration_x', y = 'acceleration_y', hue = 'is_car', data = df)

# %%
sns.relplot(x = 'acceleration_x', y = 'acceleration_z', hue = 'is_car', data = df)

# %%
sns.relplot(x = 'acceleration_y', y = 'acceleration_z', hue = 'is_car', data = df)

# %% [markdown]
# Movement more stable/does not have big variation when phone is not in car.
# When all three acceleration is near zero, data variation is high and the extreme values are ALWAYS labeled is_car.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
ax = plt.axes(projection='3d')
 (df['acceleration_x'], df['acceleration_y'], df['acceleration_z'], 'gray')

# %% [markdown]
# #### Some other visualization tools

# %%
#sns.distplot(df['acceleration_x'])
#sns.catplot(x = 'acceleration_x', kind = 'box', data = df)

# %% [markdown]
# ## Preprocessing

# %%
data = df.drop(columns = ['is_car']).values
label = df['is_car'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(data,
                                                   label,
                                                   test_size = 0.25,
                                                   random_state = 42)
X_validation, X_test, y_validation, y_test = train_test_split(X_test,
                                                   y_test,
                                                   test_size = 0.3,
                                                   random_state = 43)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(max_iter=1000)                                
logreg.fit(X_train, y_train)                                 
y_prediction = logreg.predict(X_validation)                               
acc_logreg = sum(y_prediction == y_validation)/len(y_validation)      
print('Logistic Regression: ', str(round(acc_logreg,6)))
# Out:
# Logistic Regression:  0.92519

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4, random_state = 20)
dt_classifier.fit(X_train, y_train)
dT = dt_classifier.score(X_validation, y_validation)
print('Decision Tree: ',  str(round(dT,6)))
# Out:
# Decision Tree:  0.936571
